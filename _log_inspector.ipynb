# %% [markdown]
# ## Tensorboard

# %% [markdown]
# - experiment dir: https://tensorboard.dev/experiment/FrCaqlOXRW66DdZwJx8eDQ/
# - new experiment link: https://tensorboard.dev/experiment/sabxggb4RBeiwfQlFvl6uA/

# %%
# %load_ext tensorboard

# %%
data = {
    'BetaVAE_Unbiased_2Corridors': {
        0.3 : {
            'val_rec_loss' : 0.15,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        1.0 : {
            'val_rec_loss' : 1.11,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        3.0 : {
            'val_rec_loss' : 0.07,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        6.0 : {
            'val_rec_loss' : 0.06,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        10.0 : {
            'val_rec_loss' : 0.05,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
    },
    'BetaVAE_CLF_task0': {
        0.3 : {
            'val_rec_loss' : 0.15,
            'val_clf_loss' : 3.01,
            'val_f1_score' : 0.15
        },
        1.0 : {
            'val_rec_loss' : 0.13,
            'val_clf_loss' : 2.78,
            'val_f1_score' : 0.32
        },
        3.0 : {
            'val_rec_loss' : 0.10,
            'val_clf_loss' : 2.49,
            'val_f1_score' : 0.68
        },
        6.0 : {
            'val_rec_loss' : 0.06,
            'val_clf_loss' : 2.41,
            'val_f1_score' : 0.79
        },
        10.0 : {
            'val_rec_loss' : 0.05,
            'val_clf_loss' : 2.39,
            'val_f1_score' : 0.82
        },
    },
    'BetaVAE_CLF_task1': {
        0.3 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        1.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        3.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        6.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        10.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
    },
    'BetaVAE_CLF_task2': {
        0.3 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        1.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        3.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        6.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        10.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
    },
    'BetaVAE_CLF_task3': {
        0.3 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        1.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        3.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        6.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        10.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
    },
    'BetaVAE_BottomBiasL2000R260_2Corridors': {
        0.3 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        1.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        3.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        6.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        10.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
    },
    'BetaVAE_AlignBias3000vs300_2Corridors' : {
        0.3 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        1.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        3.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        6.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
        10.0 : {
            'val_rec_loss' : None,
            'val_clf_loss' : None,
            'val_f1_score' : None
        },
    },
}

# %%
import tensorboard as tb

experiment_id = "sabxggb4RBeiwfQlFvl6uA"
experiment = tb.data.experimental.ExperimentFromDev(experiment_id)
df = experiment.get_scalars()
df
# Out:
#                                                    run       tag  step  \
# 0      BetaVAE_AlignBias3000vs300_2Corridors/max_c_0.3       KLD    49
# 1      BetaVAE_AlignBias3000vs300_2Corridors/max_c_0.3       KLD    99
# 2      BetaVAE_AlignBias3000vs300_2Corridors/max_c_0.3       KLD   149
# 3      BetaVAE_AlignBias3000vs300_2Corridors/max_c_0.3       KLD   199
# 4      BetaVAE_AlignBias3000vs300_2Corridors/max_c_0.3       KLD   249
# ...                                                ...       ...   ...
# 42054              latent_clf/Latent_CLF_task3/max_c_6  val_loss  2657
# 42055              latent_clf/Latent_CLF_task3/max_c_6  val_loss  3986
# 42056              latent_clf/Latent_CLF_task3/max_c_6  val_loss  5315
# 42057              latent_clf/Latent_CLF_task3/max_c_6  val_loss  6644
# 42058              latent_clf/Latent_CLF_task3/max_c_6  val_loss  7973
#
#           value
# 0      0.002265
# 1      0.003376
# 2      0.006109
# 3      0.008490
# 4      0.009759
# ...         ...
# 42054  0.244774
# 42055  0.246749
# 42056  0.245916
# 42057  0.245875
# 42058  0.245974
#
# [42059 rows x 4 columns]

# %%
import pandas as pd
data = pd.DataFrame([], columns=df.columns)

for a, b in df.groupby(['run', 'tag']):

    data = pd.concat(
        [data, b.iloc[-1, :].to_frame().T],
        axis=0
    )

# %%
latent_clf = data[data.run.str.startswith('latent_clf')]
latent_clf = latent_clf[~latent_clf.run.str.contains('non_linear')]
data = data[~data.run.str.startswith('latent_clf')]

# %%
data['task'] = data.run.str.split('/').str[0]
data['c'] = data.run.str.split('/').str[1].str.split('_').str[-1].astype(float)

# %%
latent_clf['task'] = latent_clf.run.str.split('/').str[1]
latent_clf['c'] = latent_clf.run.str.split('/').str[2].str.split('_').str[-1].astype(float)

# %%
task2labels = {
    'BetaVAE_CLF_task0': r'Task0 $\beta$-VAE+NonLinearCLF ',
    'BetaVAE_CLF_task1': r'Task1 $\beta$-VAE+LinearCLF ',
    'BetaVAE_CLF_task2': r'Task2 $\beta$-VAE+LinearCLF ',
    'BetaVAE_CLF_task3': r'Task3 $\beta$-VAE+LinearCLF ',
    'BetaVAE_BottomBiasL2000R260_2Corridors': r'$\beta$-VAE+BottomBias',
    'BetaVAE_AlignBias3000vs300_2Corridors': r'$\beta$-VAE+AlignBias',
    'BetaVAE_Unbiased_2Corridors': r'$\beta$-VAE Unbiased',
    'Latent_CLF_task0': r'Task0 NonLinearCLF',
    'Latent_CLF_task1': r'Task1 LinearCLF',
    'Latent_CLF_task2': r'Task2 LinearCLF',
    'Latent_CLF_task3': r'Task3 LinearCLF',
}

# %% [markdown]
# ## Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# plt.rcParams['text.usetex'] = True
# matplotlib.rcParams.update(matplotlib.rcParamsDefault)

# %% [markdown]
# ### reconstruction loss

# %% [markdown]
# #### classification task

# %%
tmp = data[
    (data.run.str.contains('CLF', regex=1)) &
    (data.tag=='val_Reconstruction_Loss')
].sort_values('task', ascending=1)
tmp['label'] = tmp.task.map(task2labels)

ax = sns.lineplot(
    data=tmp,
    x='c',
    y='value',
    hue='label',
    palette='tab10',
)

tmp = data[
    (data.run.str.contains('Unbiased', regex=1)) &
    (data.tag=='val_Reconstruction_Loss')
].sort_values('task', ascending=1)

ax = sns.lineplot(
    data=tmp,
    x='c',
    y='value',
    color='black',
    label=r'$\beta$-VAE Unbiased',
    linestyle='--',
)

ax.set_ylabel('Reconstruction Loss')
ax.set_xlabel('Capacity')
ax.grid(linestyle=':')

# %% [markdown]
# #### stat bias

# %%
tmp = data[
    (data.run.str.contains('Bias', regex=1)) &
    (data.tag=='val_Reconstruction_Loss')
].sort_values('task', ascending=1)
tmp['label'] = tmp.task.map(task2labels)

ax = sns.lineplot(
    data=tmp,
    x='c',
    y='value',
    hue='label',
)

tmp = data[
    (data.run.str.contains('Unbiased', regex=1)) &
    (data.tag=='val_Reconstruction_Loss')
].sort_values('task', ascending=1)
tmp['label'] = tmp.task.map(task2labels)

ax = sns.lineplot(
    data=tmp,
    x='c',
    y='value',
    label=r'$\beta$-VAE Unbiased',
    linestyle='--',
    color='black',
)

ax.set_ylabel('Reconstruction Loss')
ax.set_xlabel('Capacity')
ax.grid(linestyle=':')

# %% [markdown]
# ### f1 score

# %% [markdown]
# #### classification task

# %%
tmp = data[
    (data.run.str.contains('CLF|Unbiased', regex=1)) &
    (data.tag=='val_f1_score')
].sort_values('task', ascending=1)
tmp['label'] = tmp.task.map(task2labels)

ax = sns.lineplot(
    data=tmp,
    x='c',
    y='value',
    hue='label',
)

tmp = latent_clf[
    (latent_clf.run.str.contains('CLF|Unbiased', regex=1)) &
    (latent_clf.tag=='val_f1_score')
].sort_values('task', ascending=1)
tmp['label'] = tmp.task.map(task2labels)

ax1 = sns.lineplot(
    data=tmp,
    x='c',
    y='value',
    linestyle='--',
    hue='label',
    ax=ax,
)


# fix legend
handles, labels = ax.get_legend_handles_labels()
new_handles = []
new_labels = []
for handle, label in zip(handles, labels):
    if '+' not in label:
        handle.set_linestyle('--')
    new_handles.append(handle)
    new_labels.append(label)
ax.legend(new_handles, new_labels, prop={'size': 9}, loc='center right', bbox_to_anchor=(1, .3), handlelength=2.5)


ax.set_ylabel('F1 Score')
ax.set_xlabel('Capacity')
ax.grid(linestyle=':')

# %%
tmp = data[
    (data.run.str.contains('CLF|Unbiased', regex=1)) &
    (data.tag=='val_clf_loss')
].sort_values('task', ascending=1)
tmp['label'] = tmp.task.map(task2labels)

ax = sns.lineplot(
    data=tmp,
    x='c',
    y='value',
    hue='label',
)

tmp = latent_clf[
    (latent_clf.run.str.contains('CLF|Unbiased', regex=1)) &
    (latent_clf.tag=='val_loss')
].sort_values('task', ascending=1)
tmp['label'] = tmp.task.map(task2labels)

ax1 = sns.lineplot(
    data=tmp,
    x='c',
    y='value',
    linestyle='--',
    hue='label',
    ax=ax,
)


# fix legend
handles, labels = ax.get_legend_handles_labels()
new_handles = []
new_labels = []
for handle, label in zip(handles, labels):
    if '+' not in label:
        handle.set_linestyle('--')
    new_handles.append(handle)
    new_labels.append(label)
ax.legend(new_handles, new_labels, prop={'size': 9}, loc='center right', bbox_to_anchor=(1, .45), handlelength=2.5)


ax.set_ylabel('Classifier Loss')
ax.set_xlabel('Capacity')
#ax.set_yscale('log')
ax.grid(linestyle=':')

# %% [markdown]
# ---
